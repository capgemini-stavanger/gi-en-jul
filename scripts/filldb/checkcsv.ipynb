# %%
import pandas as pd

data = pd.read_csv("db_tables/1659516285/person.csv")
data.head(5)
# Out:
#                            PartitionKey                                RowKey  \
# 0  83c89050-3f4c-4fb1-b263-31d5de2612e4  06a227fa-0961-4298-8dcc-50916df2d83e
# 1  83c89050-3f4c-4fb1-b263-31d5de2612e4  20a424dc-dbe3-437b-bfab-f0575d1f6117
# 2  83c89050-3f4c-4fb1-b263-31d5de2612e4  07540cee-4034-4db1-9eda-25833e8bdea9
# 3  83c89050-3f4c-4fb1-b263-31d5de2612e4  b9a826c6-8f4e-4f37-b291-f52dcc43825a
# 4  83c89050-3f4c-4fb1-b263-31d5de2612e4  06a779ff-0d34-4f8a-8b3b-418ef6730933
#
#                   Timestamp  Age   Age@type  Months Months@type  Gender  \
# 0  2022-08-03T08:44:45.000Z  109  Edm.Int32       1  Edm.String       2
# 1  2022-08-03T08:44:45.000Z   19  Edm.Int32       1  Edm.String       1
# 2  2022-08-03T08:44:45.000Z  100  Edm.Int32       1  Edm.String       2
# 3  2022-08-03T08:44:45.000Z  116  Edm.Int32       1  Edm.String       1
# 4  2022-08-03T08:44:45.000Z  123  Edm.Int32       1  Edm.String       2
#
# ...
